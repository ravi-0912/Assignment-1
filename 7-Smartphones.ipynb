# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
path = r"C:\Users\verma\Desktop\Selenium\chromedriver.exe"

# %%
driver = webdriver.Chrome(path)

# %%
driver.get('https://www.amazon.in/s?k=mobile+phones+under+20000&rh=n%3A1389432031&dc&qid=1604132579&rnid=3576079031&ref=sr_nr_n_1')

# %%
content=driver.page_source
soup= BeautifulSoup(content)
names=soup.findAll('span',attrs={'class':'a-size-medium a-color-base a-text-normal'})
print(len(names))
amount=soup.findAll('span',attrs={'class':'a-price-whole'})
print(len(amount))
image=soup.findAll('img',attrs={'s-image'})
print(len(image))
rating=soup.findAll('span',attrs={'class':'a-icon-alt'})
print(len(rating))
# Out:
# 27
# 27
# 31
# 31

# %%
Products=[]
Price=[]
Image=[]
Rating=[]

# %%
names
# Out:
# [<span class="a-size-medium a-color-base a-text-normal" dir="auto">Nokia 5.3 Android One Smartphone with Quad Camera, 6 GB RAM and 64 GB Storage - Cyan</span>,
#  <span class="a-size-medium a-color-base a-text-normal" dir="auto">Redmi Note 9 Pro (Interstellar Black, 4GB RAM, 128GB Storage) - Latest 8nm Snapdragon 720G &amp; Alexa Hands-Free</span>,
#  <span class="a-size-medium a-color-base a-text-normal" dir="auto">Samsung Galaxy M01 (Black, 3GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers</span>,
#  <span class="a-size-medium a-color-base a-text-normal" dir="auto">Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage) – Dual Cameras &amp; 5,000 mAH Battery</span>,
#  <span class="a-size-medium a-color-base a-text-normal" dir="auto">Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128GB Storage) - Get Flat Rs 2,500 Instant Discount with select bank cards - Limited Period Offer</span>,
# ...

# %%
amount
# Out:
# [<span class="a-price-whole">14,499</span>,
#  <span class="a-price-whole">14,499</span>,
#  <span class="a-price-whole">7,999</span>,
#  <span class="a-price-whole">6,999</span>,
#  <span class="a-price-whole">18,499</span>,
#  <span class="a-price-whole">12,499</span>,
#  <span class="a-price-whole">1,185</span>,
#  <span class="a-price-whole">12,999</span>,
#  <span class="a-price-whole">11,499</span>,
#  <span class="a-price-whole">9,990</span>,
#  <span class="a-price-whole">16,499</span>,
#  <span class="a-price-whole">11,990</span>,
#  <span class="a-price-whole">7,999</span>,
#  <span class="a-price-whole">14,999</span>,
#  <span class="a-price-whole">10,990</span>,
#  <span class="a-price-whole">8,990</span>,
#  <span class="a-price-whole">5,000</span>,
#  <span class="a-price-whole">7,999</span>,
#  <span class="a-price-whole">16,499</span>,
#  <span class="a-price-whole">18,499</span>,
#  <span class="a-price-whole">12,999</span>,
# ...

# %%
image
# Out:
# [<img alt="Nokia 5.3 Android One Smartphone with Quad Camera, 6 GB RAM and 64 GB Storage - Cyan" class="s-image" data-image-index="0" data-image-latency="s-product-image" data-image-load="" data-image-source-density="1" src="https://m.media-amazon.com/images/I/61KfjV+40QL._AC_UY218_.jpg" srcset="https://m.media-amazon.com/images/I/61KfjV+40QL._AC_UY218_.jpg 1x, https://m.media-amazon.com/images/I/61KfjV+40QL._AC_UY327_FMwebp_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/61KfjV+40QL._AC_UY436_FMwebp_QL65_.jpg 2x, https://m.media-amazon.com/images/I/61KfjV+40QL._AC_UY545_FMwebp_QL65_.jpg 2.5x, https://m.media-amazon.com/images/I/61KfjV+40QL._AC_UY654_FMwebp_QL65_.jpg 3x"/>,
# ...

# %%
rating
# Out:
# [<span class="a-icon-alt">4 Stars &amp; Up</span>,
#  <span class="a-icon-alt">3 Stars &amp; Up</span>,
#  <span class="a-icon-alt">2 Stars &amp; Up</span>,
#  <span class="a-icon-alt">1 Star &amp; Up</span>,
#  <span class="a-icon-alt">3.6 out of 5 stars</span>,
#  <span class="a-icon-alt">4.2 out of 5 stars</span>,
#  <span class="a-icon-alt">3.9 out of 5 stars</span>,
#  <span class="a-icon-alt">4.0 out of 5 stars</span>,
#  <span class="a-icon-alt">4.3 out of 5 stars</span>,
#  <span class="a-icon-alt">4.2 out of 5 stars</span>,
#  <span class="a-icon-alt">4.1 out of 5 stars</span>,
#  <span class="a-icon-alt">4.2 out of 5 stars</span>,
#  <span class="a-icon-alt">4.3 out of 5 stars</span>,
#  <span class="a-icon-alt">4.2 out of 5 stars</span>,
#  <span class="a-icon-alt">4.2 out of 5 stars</span>,
#  <span class="a-icon-alt">4.2 out of 5 stars</span>,
#  <span class="a-icon-alt">4.0 out of 5 stars</span>,
#  <span class="a-icon-alt">4.2 out of 5 stars</span>,
# ...

# %%
for i in names:
    Products.append(i.text)
Products
# Out:
# ['Nokia 5.3 Android One Smartphone with Quad Camera, 6 GB RAM and 64 GB Storage - Cyan',
#  'Redmi Note 9 Pro (Interstellar Black, 4GB RAM, 128GB Storage) - Latest 8nm Snapdragon 720G & Alexa Hands-Free',
#  'Samsung Galaxy M01 (Black, 3GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage) – Dual Cameras & 5,000 mAH Battery',
#  'Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128GB Storage) - Get Flat Rs 2,500 Instant Discount with select bank cards - Limited Period Offer',
#  'Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64GB Storage)',
#  'Nokia 105 2019 (Single SIM, Black)',
#  'Redmi Note 9 Pro (Interstellar Black, 4GB RAM, 64GB Storage)- Latest 8nm Snapdragon 720G & Alexa Hands-Free',
#  'Redmi Note 8 (Neptune Blue, 4GB RAM, 64GB Storage) | Snapdragon 665 Processor | 48 MP Quad Camera',
#  'OPPO A5 2020 (Mirror Black, 3GB RAM, 64GB Storage) with No Cost EMI/Additional Exchange Offers',
# ...

# %%
df=pd.DataFrame(Products)
df=df.rename({0:'Product Name'},axis=1)
df
# Out:
#                                          Product Name
# 0   Nokia 5.3 Android One Smartphone with Quad Cam...
# 1   Redmi Note 9 Pro (Interstellar Black, 4GB RAM,...
# 2   Samsung Galaxy M01 (Black, 3GB RAM, 32GB Stora...
# 3   Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage...
# 4   Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128...
# 5   Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64...
# 6                  Nokia 105 2019 (Single SIM, Black)
# 7   Redmi Note 9 Pro (Interstellar Black, 4GB RAM,...
# 8   Redmi Note 8 (Neptune Blue, 4GB RAM, 64GB Stor...
# 9   OPPO A5 2020 (Mirror Black, 3GB RAM, 64GB Stor...
# 10  Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...
# 11  OPPO A5 2020 (Dazzling White, 4GB RAM, 64GB St...
# 12  Redmi 8A Dual (Sea Blue, 3GB RAM, 32GB Storage...
# 13  Samsung Galaxy M21 (Raven Black, 6GB RAM, 128G...
# 14     OPPO A15 (Mystery Blue, 3GB RAM, 32GB Storage)
# 15  OPPO A5S (Black, 3GB RAM, 32GB Storage) With N...
# ...

# %%
for i in amount:
    Price.append(i.text)
Price
# Out:
# ['14,499',
#  '14,499',
#  '7,999',
#  '6,999',
#  '18,499',
#  '12,499',
#  '1,185',
#  '12,999',
#  '11,499',
#  '9,990',
#  '16,499',
#  '11,990',
#  '7,999',
#  '14,999',
#  '10,990',
#  '8,990',
#  '5,000',
#  '7,999',
#  '16,499',
#  '18,499',
#  '12,999',
#  '7,825',
#  '10,990',
#  '16,990',
#  '6,999',
#  '12,499',
#  '6,999']

# %%
df1=pd.DataFrame(Price)
df1=df1.rename({0:'Price'},axis=1)
df1
# Out:
#      Price
# 0   14,499
# 1   14,499
# 2    7,999
# 3    6,999
# 4   18,499
# 5   12,499
# 6    1,185
# 7   12,999
# 8   11,499
# 9    9,990
# 10  16,499
# 11  11,990
# 12   7,999
# 13  14,999
# 14  10,990
# 15   8,990
# 16   5,000
# 17   7,999
# 18  16,499
# 19  18,499
# 20  12,999
# 21   7,825
# 22  10,990
# 23  16,990
# 24   6,999
# 25  12,499
# 26   6,999

# %%
for i in image:
    Image.append(i.get('src'))
print(len(Image))
Image
# Out:
# 31
# ['https://m.media-amazon.com/images/I/61KfjV+40QL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/91Lr-OxVKjL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81onqHVeECL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71yXShgxvpL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61d-phh4GfL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71dujTTJDZL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/31Z2ee9oYQL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/91Lr-OxVKjL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61Z-7BVaFUL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/514zYTXaCqL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71-Su4Wr0HL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71wPwmxo2NL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71yXShgxvpL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71QLvGIAq5L._AC_UY218_.jpg',
# ...

# %%
df2=pd.DataFrame(Image)
df2=df2.rename({0:'Image Url'},axis=1)
df2=df2.iloc[0:27]
df2
# Out:
#                                             Image Url
# 0   https://m.media-amazon.com/images/I/61KfjV+40Q...
# 1   https://m.media-amazon.com/images/I/91Lr-OxVKj...
# 2   https://m.media-amazon.com/images/I/81onqHVeEC...
# 3   https://m.media-amazon.com/images/I/71yXShgxvp...
# 4   https://m.media-amazon.com/images/I/61d-phh4Gf...
# 5   https://m.media-amazon.com/images/I/71dujTTJDZ...
# 6   https://m.media-amazon.com/images/I/31Z2ee9oYQ...
# 7   https://m.media-amazon.com/images/I/91Lr-OxVKj...
# 8   https://m.media-amazon.com/images/I/61Z-7BVaFU...
# 9   https://m.media-amazon.com/images/I/514zYTXaCq...
# 10  https://m.media-amazon.com/images/I/71-Su4Wr0H...
# 11  https://m.media-amazon.com/images/I/71wPwmxo2N...
# 12  https://m.media-amazon.com/images/I/71yXShgxvp...
# 13  https://m.media-amazon.com/images/I/71QLvGIAq5...
# 14  https://m.media-amazon.com/images/I/71y3aWvOuc...
# 15  https://m.media-amazon.com/images/I/71ZU4Vsevq...
# ...

# %%
 for i in rating:
    Rating.append(i.text)
Rating
# Out:
# ['4 Stars & Up',
#  '3 Stars & Up',
#  '2 Stars & Up',
#  '1 Star & Up',
#  '3.6 out of 5 stars',
#  '4.2 out of 5 stars',
#  '3.9 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.3 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.3 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.2 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.1 out of 5 stars',
#  '3.2 out of 5 stars',
#  '3.9 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '3.9 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
df3=pd.DataFrame(Rating)
df3=df3.rename({0:'Rating'},axis=1)
df3=df3.iloc[4:]
df3=df3.reset_index(drop=True)
df3
# Out:
#                 Rating
# 0   3.6 out of 5 stars
# 1   4.2 out of 5 stars
# 2   3.9 out of 5 stars
# 3   4.0 out of 5 stars
# 4   4.3 out of 5 stars
# 5   4.2 out of 5 stars
# 6   4.1 out of 5 stars
# 7   4.2 out of 5 stars
# 8   4.3 out of 5 stars
# 9   4.2 out of 5 stars
# 10  4.2 out of 5 stars
# 11  4.2 out of 5 stars
# 12  4.0 out of 5 stars
# 13  4.2 out of 5 stars
# 14  5.0 out of 5 stars
# 15  4.1 out of 5 stars
# 16  3.2 out of 5 stars
# 17  3.9 out of 5 stars
# 18  4.2 out of 5 stars
# 19  4.1 out of 5 stars
# 20  4.2 out of 5 stars
# 21  3.9 out of 5 stars
# 22  4.2 out of 5 stars
# 23  4.0 out of 5 stars
# 24  4.0 out of 5 stars
# 25  4.2 out of 5 stars
# 26  4.0 out of 5 stars

# %%
Smartphone=pd.concat([df,df1,df2,df3],axis=1)
Smartphone.index=range(27)
Smartphone
# Out:
#                                          Product Name   Price  \
# 0   Nokia 5.3 Android One Smartphone with Quad Cam...  14,499
# 1   Redmi Note 9 Pro (Interstellar Black, 4GB RAM,...  14,499
# 2   Samsung Galaxy M01 (Black, 3GB RAM, 32GB Stora...   7,999
# 3   Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage...   6,999
# 4   Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128...  18,499
# 5   Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64...  12,499
# 6                  Nokia 105 2019 (Single SIM, Black)   1,185
# 7   Redmi Note 9 Pro (Interstellar Black, 4GB RAM,...  12,999
# 8   Redmi Note 8 (Neptune Blue, 4GB RAM, 64GB Stor...  11,499
# 9   OPPO A5 2020 (Mirror Black, 3GB RAM, 64GB Stor...   9,990
# 10  Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...  16,499
# 11  OPPO A5 2020 (Dazzling White, 4GB RAM, 64GB St...  11,990
# 12  Redmi 8A Dual (Sea Blue, 3GB RAM, 32GB Storage...   7,999
# 13  Samsung Galaxy M21 (Raven Black, 6GB RAM, 128G...  14,999
# ...

# %% [markdown]
# # Saving Smartphone Data into csv file

# %%
Smartphone.to_csv("Smartphones_under_20000.csv")
